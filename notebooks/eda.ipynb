# %% [markdown]
# # EDA - Exploratory Data Analisys

# %%
data_path = '../data/house_data.parquet'
processed_data_path = '../data/house_data_processed.parquet'
import pandas as pd
from pathlib import Path

# %%
df = pd.read_parquet(data_path)
df.head()
# Out:
#           id          total     area  bedroom_qtd    garage  \
# 0  894438651    R$ 860.000    96 m²    2 quartos    2 vagas
# 1  894959499  R$ 2.530.000   182 m²    3 quartos    3 vagas
# 2  895093734    R$ 235.000    38 m²     2 quartos         0
# 3  894798128    R$ 298.000    52 m²    2 quartos     1 vaga
# 4  894890195  R$ 2.600.000   220 m²    3 quartos    3 vagas
#
#                                     address       state
# 0     Rua Francisco José da Silva, Morumbi    São Paulo
# 1  Rua Leonardo Cerveira Varandas, Morumbi    São Paulo
# 2            Rua Leandro Teixeira, Morumbi    São Paulo
# 3          Rua José Dias da Costa, Morumbi    São Paulo
# 4          Rua Adalívia de Toledo, Morumbi    São Paulo

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           996 non-null    str
#  1   total        996 non-null    str
#  2   area         996 non-null    str
#  3   bedroom_qtd  996 non-null    str
#  4   garage       996 non-null    str
#  5   address      996 non-null    str
#  6   state        996 non-null    str
# dtypes: str(7)
# memory usage: 148.1 KB

# %%
df.isna().sum().sort_values()
# Out:
# id             0
# total          0
# area           0
# bedroom_qtd    0
# garage         0
# address        0
# state          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_processed = pd.read_parquet(processed_data_path)
df_processed.head()
# Out:
#           id      total   area  bedroom_qtd  garage  \
# 0  894438651   860000.0   96.0            2       2
# 1  894959499  2530000.0  182.0            3       3
# 2  895093734   235000.0   38.0            2       0
# 3  894798128   298000.0   52.0            2       1
# 4  894890195  2600000.0  220.0            3       3
#
#                           address       state   district
# 0     Rua Francisco José da Silva   São Paulo   Morumbi
# 1  Rua Leonardo Cerveira Varandas   São Paulo   Morumbi
# 2            Rua Leandro Teixeira   São Paulo   Morumbi
# 3          Rua José Dias da Costa   São Paulo   Morumbi
# 4          Rua Adalívia de Toledo   São Paulo   Morumbi

# %%
df_processed.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           996 non-null    str
#  1   total        996 non-null    float64
#  2   area         996 non-null    float64
#  3   bedroom_qtd  996 non-null    int64
#  4   garage       996 non-null    int64
#  5   address      996 non-null    str
#  6   state        996 non-null    str
#  7   district     996 non-null    str
# dtypes: float64(2), int64(2), str(4)
# memory usage: 117.9 KB

# %%
df_processed.describe()
# Out:
#               total         area  bedroom_qtd      garage
# count  9.960000e+02   996.000000   996.000000  996.000000
# mean   1.167506e+06   135.232932     2.644578    2.060241
# std    1.239147e+06   113.961794     0.955377    1.351859
# min    2.000000e+05    12.000000     1.000000    0.000000
# 25%    4.898750e+05    60.750000     2.000000    1.000000
# 50%    8.225000e+05   100.000000     3.000000    2.000000
# 75%    1.350000e+06   170.000000     3.000000    3.000000
# max    1.416000e+07  1040.000000     6.000000    8.000000

# %%
df_processed[['total', 'area', 'bedroom_qtd', 'garage']].corr(method='pearson')
# Out:
#                 total      area  bedroom_qtd    garage
# total        1.000000  0.677220     0.314993  0.596771
# area         0.677220  1.000000     0.608735  0.778583
# bedroom_qtd  0.314993  0.608735     1.000000  0.667917
# garage       0.596771  0.778583     0.667917  1.000000
