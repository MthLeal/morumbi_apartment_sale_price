# %% [markdown]
# # EDA - Exploratory Data Analisys

# %%
data_path = '../data/house_data.parquet'
import pandas as pd

# %%
df = pd.read_parquet(data_path)
df.head()
# Out:
#           id        total    area bedroom_qtd garage  \
# 0  895423894  R$ 200.000   27 m²     1 quarto      0
# 1  895160278  R$ 200.000   17 m²     1 quarto      0
# 2  895162134  R$ 200.000   17 m²     1 quarto      0
# 3  894853599  R$ 200.000   15 m²     1 quarto      0
# 4  895394790  R$ 200.000   50 m²    2 quartos      0
#
#                                    address       state
# 0           Rua Leandro Teixeira, Morumbi    São Paulo
# 1     Rua Dias Vieira, Jardim Monte Kemel    São Paulo
# 2     Rua Dias Vieira, Jardim Monte Kemel    São Paulo
# 3     Rua Dias Vieira, Jardim Monte Kemel    São Paulo
# 4  Rua Doutor Laerte Setúbal, Vila Suzana    São Paulo

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           39 non-null     str
#  1   total        39 non-null     str
#  2   area         39 non-null     str
#  3   bedroom_qtd  39 non-null     str
#  4   garage       39 non-null     str
#  5   address      39 non-null     str
#  6   state        39 non-null     str
# dtypes: str(7)
# memory usage: 5.4 KB
